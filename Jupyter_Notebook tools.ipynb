# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Data Science Experience</h1>

# %% [markdown]
# <h3>Introduction</h3>
# Data science is an interseting field that requires a variety of programming skills to solve complicated problems, and soft skills like story telling to convey solutions to others.

# %% [markdown]
# <h3> List of data science languages </h3>
# <ul>
# <li>Python</li>
# <li>SQL</li>
# <li>R</li>
# </ul>

# %% [markdown]
# <h3> List of data science libraries </h3>
# <ul>
# <li>Pandas</li>
# <li>Seaborn</li>
# <li>Scikit-learn</li>
# </ul>

# %% [markdown]
# <h3> List of data science tools </h3>
# <table>
# <tr>
# <td>Apache</td>
# <td>tensorFlow</td>
# <td>Hadoop</td>
# </tr>
# </tables>

# %% [markdown]
# Arithmetic expression examples:
# 2+2=4
# 6/2=3
# 3*2=6

# %%
x=3*2
y=2+2
print(x,y)
# Out:
# 6 4

# %%
#Converting minutes to hours.
minute=int(input("Enter number of minutes"))
hours= minute/60 # we ll choose 30
print(hours)
# Out:
# 0.5

# %% [markdown]
# <h3>List of objectives</h3>
# <ul>
# <li>Becoming a succesfull data scientist</li>
# <li>Improving public talking</li>
# <li>Visiting dream countries</li>
# </ul>

# %% [markdown]
# My name is El Wafi Akram
